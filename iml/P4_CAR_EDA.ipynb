# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_data = pd.read_csv('/content/EDA Cars - Sheet1.csv')
df_data.head()
# Out:
#    INDEX       INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0      1  125301.2425             No   F    Bachelors  Blue Collar
# 1      2  50815.44531             No   M  High School          NaN
# 2      3  62977.82416            NaN   F    Bachelors     Clerical
# 3      4  77099.96624             No   F          NaN       Lawyer
# 4      5  130794.5742             No   M  High School          NaN
#
#    TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE   CITY  \
# 0    45.703013  Commercial        17430.0   Sports Car      7.0  Texas
# 1    20.591628     Private        18930.0      Minivan      1.0  Texas
# 2    33.639949     Private            NaN          SUV      1.0  Texas
# 3    15.415676         NaN        18300.0   Sports Car     11.0  Texas
# 4          NaN  Commercial        28340.0  Panel Truck     10.0  Texas
#
#    POSTAL CODE
# 0      42420.0
# 1      42420.0
# 2      42420.0
# 3      42420.0
# 4      42420.0

# %%
df_data.tail()
# Out:
#      INDEX       INCOME MARITAL STATUS SEX    EDUCATION       JOB  \
# 298    285  15251.52473             No   M  High School  Clerical
# 299    286  18408.39545             No   M  High School  Clerical
# 300    287          NaN             No   M  High School  Clerical
# 301    288          NaN            Yes   F  High School       NaN
# 302    289            0             No   M    Bachelors   Student
#
#      TRAVEL TIME         USE  MILES CLOCKED    CAR TYPE  CAR AGE       CITY  \
# 298    31.315058     Private         3030.0  Sports Car      1.0  Las Vegas
# 299    42.619118     Private         7440.0         NaN      1.0  Las Vegas
# 300    36.533624     Private         7660.0         SUV      NaN  Las Vegas
# 301    60.884292     Private        19550.0         Van      1.0  Las Vegas
# 302    11.657483  Commercial        19940.0         SUV      7.0  Las Vegas
#
#      POSTAL CODE
# 298      44412.0
# 299          NaN
# 300      44412.0
# 301      44412.0
# 302      44412.0

# %%
df_data.shape
# Out:
# (303, 13)

# %%
df_data.describe()
# Out:
#             INDEX  TRAVEL TIME  MILES CLOCKED     CAR AGE   POSTAL CODE
# count  303.000000   262.000000     278.000000  283.000000    300.000000
# mean   139.640264    34.282098   13591.978417    6.265018  50712.196667
# std     85.178422    14.910178    7167.328655    5.111218  24141.029290
# min      1.000000     5.000000    1500.000000    1.000000  11435.000000
# 25%     62.500000    24.449874    7900.000000    1.000000  42420.000000
# 50%    138.000000    33.564757   12065.000000    6.000000  47150.000000
# 75%    213.500000    43.907339   18240.000000   10.000000  61701.000000
# max    289.000000    83.617643   38000.000000   20.000000  90049.000000

# %%
df_data.isnull().sum()
# Out:
# INDEX              0
# INCOME            38
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          265 non-null    object
#  2   MARITAL STATUS  275 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   278 non-null    float64
#  9   CAR TYPE        293 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 30.9+ KB

# %%
df_data.columns
# Out:
# Index(['INDEX', 'INCOME', 'MARITAL STATUS', 'SEX', 'EDUCATION', 'JOB',
#        'TRAVEL TIME', 'USE', 'MILES CLOCKED', 'CAR TYPE', 'CAR AGE', 'CITY',
#        'POSTAL CODE'],
#       dtype='object')

# %%
df_data.duplicated().sum()
# Out:
# 14

# %%
df_data.nunique()
# Out:
# INDEX             289
# INCOME            222
# MARITAL STATUS      2
# SEX                 2
# EDUCATION           4
# JOB                 8
# TRAVEL TIME       243
# USE                 2
# MILES CLOCKED     240
# CAR TYPE            6
# CAR AGE            19
# CITY               11
# POSTAL CODE        11
# dtype: int64

# %%
df_data['INCOME'].value_counts()
# Out:
# INCOME
# 0              25
# 64013.81632    15
# @@              5
# 91221.1218      2
# 125301.2425     1
#                ..
# 66367.40477     1
# 29523.52225     1
# 94591.18428     1
# 248.614532      1
# 18408.39545     1
# Name: count, Length: 222, dtype: int64

# %%
df_data.nunique()
# Out:
# INDEX             289
# INCOME            222
# MARITAL STATUS      2
# SEX                 2
# EDUCATION           4
# JOB                 8
# TRAVEL TIME       243
# USE                 2
# MILES CLOCKED     240
# CAR TYPE            6
# CAR AGE            19
# CITY               11
# POSTAL CODE        11
# dtype: int64

# %%
df_data['MARITAL STATUS'].value_counts()
# Out:
# MARITAL STATUS
# No     151
# Yes    124
# Name: count, dtype: int64

# %%
df_data['MILES CLOCKED'].value_counts()
# Out:
# MILES CLOCKED
# 7900.0     15
# 1500.0      6
# 5800.0      3
# 6000.0      3
# 7200.0      3
#            ..
# 5560.0      1
# 14250.0     1
# 19530.0     1
# 10590.0     1
# 19940.0     1
# Name: count, Length: 240, dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          265 non-null    object
#  2   MARITAL STATUS  275 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   278 non-null    float64
#  9   CAR TYPE        293 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 30.9+ KB

# %%
df_data.drop_duplicates(subset=None, keep='first', inplace=True)
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data = df_data.drop(['POSTAL CODE'],axis = 1)

# %%
df_data = df_data.select_dtypes(include=['float64', 'int64'])
corr = df_data.corr()
sns.heatmap(corr,annot=True,cmap='Reds')
# Out:
# <Axes: >

# %%
sns.countplot(x=df_data['CAR TYPE'])
# Out:
# <Axes: xlabel='CAR TYPE', ylabel='count'>

# %%
sns.pairplot(df_data, hue = 'CAR TYPE')

# %%
sns.countplot(x = 'CAR TYPE',data = df_data,palette = 'rainbow')
# Out:
# <ipython-input-52-06161ed11f46>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'CAR TYPE',data = df_data,palette = 'rainbow')
# <Axes: xlabel='CAR TYPE', ylabel='count'>

# %%
df_data['CAR AGE'].value_counts()
# Out:
# CAR AGE
# 1.0     98
# 5.0     26
# 10.0    21
# 8.0     21
# 6.0     19
# 7.0     16
# 11.0    15
# 9.0     12
# 4.0     11
# 12.0     7
# 14.0     6
# 20.0     6
# 18.0     5
# 3.0      5
# 16.0     4
# 13.0     4
# 17.0     3
# 15.0     3
# 19.0     1
# Name: count, dtype: int64

# %%
sns.countplot(x='CAR AGE',data=df_data,palette='tab10')
# Out:
# <ipython-input-55-69c05cf6c761>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='CAR AGE',data=df_data,palette='tab10')
# <Axes: xlabel='CAR AGE', ylabel='count'>

# %%
df_data['POSTAL CODE'].value_counts().plot.pie(autopct='dark')
plt.show()

# %%
df_data['CAR TYPE'].value_counts().plot.pie(autopct='dark')
plt.show()
