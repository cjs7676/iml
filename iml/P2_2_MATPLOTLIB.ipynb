# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.barh(x,y, color = "green", height = 0.1)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y, color = "#FFA500", width = 0.1)
plt.show()

# %%
test = pd.read_csv('Downloads/petrol_consumption - petrol_consumption.csv')
df = pd.DataFrame(test)
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
x = df.Average_income
y = df.Petrol_Consumption
plt.bar(x,y , width = 1)
plt.show()

# %%
z = np.random.normal(170, 10, 250)
print(z)
plt.hist(z)
plt.show()
# Out:
# [172.42752956 172.56816997 189.0148825  152.00070086 175.66497468
#  159.94585864 175.27860475 165.56751579 153.83937691 154.63926541
#  163.72319703 173.45920032 180.45960964 176.29653932 189.85677344
#  174.64022993 175.93918115 166.20092749 152.10194067 173.02213062
#  169.14018856 158.23814547 177.67165493 172.74139712 175.32227748
#  163.94548413 154.37460549 160.29950992 182.39645632 170.82488884
#  174.9179462  181.96839746 178.18239627 164.52112067 183.91340945
#  150.7953568  172.24315799 157.77049788 172.34304657 146.48577315
#  175.39509176 172.17718579 161.59592994 157.38159976 180.29815358
#  162.78821949 163.22234681 162.6518606  181.045362   168.59187921
#  172.50441744 191.62800174 135.73453433 179.3920637  170.08955743
#  162.93563098 162.54137825 170.9182812  153.10763114 172.30587567
#  170.86808678 160.22905133 168.78006149 179.90912937 161.94495657
#  165.69555162 171.76199116 155.80283655 162.63402665 167.33694628
# ...

# %%
data = df.Average_income
plt.hist(data)
plt.show()

# %%
data2 = np.array([35, 25, 25, 15])
mylabels = ["APPLES", "BANANAS", "CHERRIES", "DATES"]
plt.pie(data2, labels = mylabels)
plt.legend()
plt.show()

# %%
plt.pie(data)
plt.show()

# %%
data2 = np.array([35, 25, 25, 15])
mylabels = ["APPLES", "BANANAS", "CHERRIES", "DATES"]
plt.pie(data2, labels = mylabels, startangle = 90)
plt.show()

# %%
data2 = np.array([35, 25, 25, 15])
mylabels = ["APPLES", "BANANAS", "CHERRIES", "DATES"]
myexplode = [0.2, 0, 0, 0]
plt.pie(data2, labels = mylabels, explode = myexplode, shadow = True)
plt.show()
