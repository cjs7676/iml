# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randn(4,4), columns = ['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -1.598924 -1.178124 -0.190403 -1.632364
# 1 -0.435749 -0.219835 -0.922664 -1.424278
# 2  1.154704  0.684492 -0.106332  1.317350
# 3 -0.472030  0.342618  0.627964 -0.864306

# %%
s = df.iloc[3]
s
# Out:
# A   -0.472030
# B    0.342618
# C    0.627964
# D   -0.864306
# Name: 3, dtype: float64

# %%
pd.concat([df, pd.DataFrame([s])], ignore_index=True)
# Out:
#           A         B         C         D
# 0 -1.598924 -1.178124 -0.190403 -1.632364
# 1 -0.435749 -0.219835 -0.922664 -1.424278
# 2  1.154704  0.684492 -0.106332  1.317350
# 3 -0.472030  0.342618  0.627964 -0.864306
# 4 -0.472030  0.342618  0.627964 -0.864306

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum','Yum Yum','Indomie','Indomie','Indomie'],
    'style': ['cup','cup','cup','pack','pack'],
    'rating': [4, 4, 3.5, 15, 5]})
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates()
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0
