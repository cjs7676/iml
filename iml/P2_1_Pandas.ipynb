# %%
import pandas as pd

mydict ={'red':2000, 'blue':1000, 'yellow':500, 'orange':1000}
myseries = pd.Series(mydict)
myseries
# Out:
# red       2000
# blue      1000
# yellow     500
# orange    1000
# dtype: int64

# %%
mydict
# Out:
# {'red': 2000, 'blue': 1000, 'yellow': 500, 'orange': 1000}

# %%
colors =['red', 'blue', 'yellow', 'orange', 'green']
myseries1 = pd.Series(mydict, index=colors)
myseries1
# Out:
# red       2000.0
# blue      1000.0
# yellow     500.0
# orange    1000.0
# green        NaN
# dtype: float64

# %%
mydict2 ={'red':400, 'yellow':1000, 'black':700}
myseries2 = pd.Series(mydict2)
myseries+myseries2
# Out:
# black        NaN
# blue         NaN
# orange       NaN
# red       2400.0
# yellow    1500.0
# dtype: float64

# %%
data = {'color' : ['red', 'blue', 'yellow', 'orange', 'black'],
          'object' : ['ball','pen','pencil','paper','mug'],
          'price' : [1.2,1.0,0.6,0.9,1.7]}
frame = pd.DataFrame(data)
frame
# Out:
#     color  object  price
# 0     red    ball    1.2
# 1    blue     pen    1.0
# 2  yellow  pencil    0.6
# 3  orange   paper    0.9
# 4   black     mug    1.7

# %%
frame2 = pd.DataFrame(data, index=['one','two','three','four','five'])
frame2
# Out:
#         color  object  price
# one       red    ball    1.2
# two      blue     pen    1.0
# three  yellow  pencil    0.6
# four   orange   paper    0.9
# five    black     mug    1.7

# %%
import numpy as np

frame3 = pd.DataFrame(np.arange(16).reshape((4,4)),
                      index=['red','blue','yellow','white'],
                      columns=['ball','pen','pencil','paper'])
frame3
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
frame['new'] = 20
frame
# Out:
#     color  object  price  new
# 0     red    ball    1.2   20
# 1    blue     pen    1.0   20
# 2  yellow  pencil    0.6   20
# 3  orange   paper    0.9   20
# 4   black     mug    1.7   20

# %%
frame[frame.isin([1.0,'pen'])]
# Out:
#   color object  price  new
# 0   NaN    NaN    NaN  NaN
# 1   NaN    pen    1.0  NaN
# 2   NaN    NaN    NaN  NaN
# 3   NaN    NaN    NaN  NaN
# 4   NaN    NaN    NaN  NaN

# %%
del frame['new']
frame
# Out:
#     color  object  price
# 0     red    ball    1.2
# 1    blue     pen    1.0
# 2  yellow  pencil    0.6
# 3  orange   paper    0.9
# 4   black     mug    1.7

# %%
nestdict = {'red': {2012: 22, 2013: 33},
            'white': {2011: 13, 2012: 22, 2013: 16},
            'blue': {2011: 17, 2012: 27, 2013: 18}}
nestdict
# Out:
# {'red': {2012: 22, 2013: 33},
#  'white': {2011: 13, 2012: 22, 2013: 16},
#  'blue': {2011: 17, 2012: 27, 2013: 18}}

# %%
frame2 = pd.DataFrame(nestdict)
frame2
# Out:
#        red  white  blue
# 2012  22.0     22    27
# 2013  33.0     16    18
# 2011   NaN     13    17

# %%
ser = pd.Series([2,5,7,4], index=['one', 'two', 'three', 'four'])
ser
# Out:
# one      2
# two      5
# three    7
# four     4
# dtype: int64

# %%
ser.reindex(['three', 'four', 'five', 'one'])
# Out:
# three    7.0
# four     4.0
# five     NaN
# one      2.0
# dtype: float64

# %%
ser3 = pd.Series([1,5,6,3], index=[0,3,5,6])
ser3
# Out:
# 0    1
# 3    5
# 5    6
# 6    3
# dtype: int64

# %%
ser3.reindex(range(6),method='ffill')
# Out:
# 0    1
# 1    1
# 2    1
# 3    5
# 4    5
# 5    6
# dtype: int64

# %%
pd.read_csv('/content/animal.csv')
# Out:
#    white  red  blue  green animal
# 0      1    1     2      3    cat
# 1      2    2     8      5    dog
# 2      3    3     6      7  horse
# 3      2    2     8      3   duck
# 4      4    4     2      1  mouse

# %%
pd.read_csv('/content/animal.csv', header=None)
# Out:
#        0    1     2      3       4
# 0  white  red  blue  green  animal
# 1      1    1     2      3     cat
# 2      2    2     8      5     dog
# 3      3    3     6      7   horse
# 4      2    2     8      3    duck
# 5      4    4     2      1   mouse

# %%
pd.read_csv('/content/animal.csv', names=['col1','col2','col3','col4','col5'])
# Out:
#     col1 col2  col3   col4    col5
# 0  white  red  blue  green  animal
# 1      1    1     2      3     cat
# 2      2    2     8      5     dog
# 3      3    3     6      7   horse
# 4      2    2     8      3    duck
# 5      4    4     2      1   mouse

# %%
text_file = open("/content/name.txt", "r")
lines = text_file.read()
lines
# Out:
# 'my name is mihir'
